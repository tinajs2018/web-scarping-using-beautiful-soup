# %%
#importing vital libraries
import requests
from bs4 import BeautifulSoup
import re

# %%
aricle=[]
url='https://itsfoss.com/update-ubuntu/'

# %%
r=requests.get(url)

# %%
html_soup=BeautifulSoup(r.text,'html.parser')
html_soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en-US">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# ...

# %%
for item in html_soup.find_all('li'):
    item_a=item.find('h2')
    item_link=item_a.get('href') if item_a else None
    item_text=item_a.get_text(strip=True) if item_a else None
    next_row=item.find_next_sibling('li')
    item_score=next_row.find('span')
    item_score=item_score.get_text(strip=True) if item_score else '0 points'
    # we use  regex here to find the correct element
#     item_comments=next_row.find('a',string=re.compile('\d+(&nbsp;|\s)comment(s?'))
#     item_comments=item_comments.get_text(strip=True).replace ('\xa0', ' ')  if  item_comments else '0 comments'
    aricle.append({
        'link':item_link,
        'title':item_text,
        'score': item_score,
#         'comments':item_comments
    })
for  aricle in  aricles:
     print( aricle)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-c52aca155d33> in <module>
#       4     item_text=item_a.get_text(strip=True) if item_a else None
#       5     next_row=item.find_next_sibling('li')
# ----> 6     item_score=next_row.find('span')
#       7     item_score=item_score.get_text(strip=True) if item_score else '0 points'
#       8     # we use  regex here to find the correct element
#
# AttributeError: 'NoneType' object has no attribute 'find'

# %%
for item in html_soup.find_all('tr'):
    item_a = item.find('a')
    item_link = item_a.get('href') if item_a else None
    item_text = item_a.get_text(strip=True) if item_a else None
    next_row = item.find_next_sibling('tr')
    item_score = next_row.find('span' )
    item_score = item_score.get_text(strip=True) if item_score else '0 points'
    # We use regex here to find the correct element
#     item_comments = next_row.find('a', string=re.compile('\d+(&nbsp;|\s)comment(s?)'))
#     item_comments = item_comments.get_text(strip=True).replace('\xa0', ' ') \
#                         if item_comments else '0 comments
                                                          
                                                          
    articles.append({
        'link' : item_link,
        'title' : item_text,
        'score' : item_score,
        'comments' : item_comment})

for  aricle in  aricles:
    print( aricle)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-a92ae2bd62e4> in <module>
#      18         'comments' : item_comment})
#      19
# ---> 20 for  aricle in  aricles:
#      21     print( aricle)
#      22
#
# NameError: name 'aricles' is not defined
