# %%
import requests

# %%
res=requests.get('https://www.analyticsvidhya.com/blog/2021/06/data-extraction-from-unstructured-pdfs/#:~:text=There%20are%20a%20couple%20of,PDFs%20through%20the%20Camelot%20library.')

# %%
print(res.text)
# Out:
# <!doctype html>
# <html lang="en">
# <head>
# <meta charset="utf-8">
# <meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no">
# <meta name="format-detection" content="telephone=no">
# <meta name="format-detection" content="address=no">
# <link rel='icon' id='favicon' type='image/x-icon' href='https://www.analyticsvidhya.com/wp-content/uploads/2015/02/logo_square_v2.jpg'>
# <link rel='apple-touch-icon' href='https://www.analyticsvidhya.com/wp-content/uploads/2015/02/logo_square_v2.jpg'>
# <link rel='apple-touch-icon' sizes='76x76' href='https://www.analyticsvidhya.com/wp-content/uploads/2015/02/logo_square_v2.jpg'>
# <link rel='apple-touch-icon' sizes='114x114' href='https://www.analyticsvidhya.com/wp-content/uploads/2015/02/logo_square_v2.jpg'>
# <link rel='apple-touch-icon' sizes='144x144' href='https://www.analyticsvidhya.com/wp-content/uploads/2015/02/logo_square_v2.jpg'>
# ...

# %%
print(res.status_code)
# Out:
# 200

# %%
from bs4 import BeautifulSoup

# %%
page= requests.get('https://www.analyticsvidhya.com/blog/2021/06/data-extraction-from-unstructured-pdfs/#:~:text=There%20are%20a%20couple%20of,PDFs%20through%20the%20Camelot%20library.')

# %%
soup= BeautifulSoup(page.content,'html.parser')

# %%
page_title=soup.title.text

# %%
print(page_title)
# Out:
# Data Extraction from Unstructured PDFs - Analytics Vidhya

# %%
#extracting  the body of the page
page_body=soup.body
print(page_body)
# Out:
# <body class="av-detail-page">
# <div class="blog-detail-page">
# <div class="overlay"></div>
# <header class="bg-white common-header">
# <div class="container">
# <div class="row">
# <nav class="navbar navbar-expand-lg w-100">
# <a class="navbar-brand" href="https://www.analyticsvidhya.com/blog/">
# <img alt="Analytics Vidhya" src="https://av-public-assets.s3.ap-south-1.amazonaws.com/logos/av-logo-svg.svg"/>
# </a>
# <div id="AvSearchBox">
# <form action="https://www.analyticsvidhya.com" method="GET">
# <div class="col-auto p-0">
# <label class="sr-only" for="inlineFormSearch">search</label>
# <div class="input-group">
# <input autocomplete="off" class="form-control" id="inlineFormSearch" name="s" placeholder="Search" type="text" value=""/>
# <div class="input-group-prepend" id="CloseSearch">
# <div class="input-group-text">
# <i class="fas fa-times"></i>
# </div>
# </div>
# </div>
# </div>
# </form>
# </div>
# ...

# %%
#extracting the head of the page
page_head=soup.head
print(page_head)
# Out:
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1, shrink-to-fit=no" name="viewport"/>
# <meta content="telephone=no" name="format-detection"/>
# <meta content="address=no" name="format-detection"/>
# <link href="https://www.analyticsvidhya.com/wp-content/uploads/2015/02/logo_square_v2.jpg" id="favicon" rel="icon" type="image/x-icon"/>
# <link href="https://www.analyticsvidhya.com/wp-content/uploads/2015/02/logo_square_v2.jpg" rel="apple-touch-icon"/>
# <link href="https://www.analyticsvidhya.com/wp-content/uploads/2015/02/logo_square_v2.jpg" rel="apple-touch-icon" sizes="76x76"/>
# <link href="https://www.analyticsvidhya.com/wp-content/uploads/2015/02/logo_square_v2.jpg" rel="apple-touch-icon" sizes="114x114"/>
# <link href="https://www.analyticsvidhya.com/wp-content/uploads/2015/02/logo_square_v2.jpg" rel="apple-touch-icon" sizes="144x144"/>
# <link href="https://cdnjs.cloudflare.com/ajax/libs/animate.css/4.1.0/animate.min.css" rel="stylesheet">
# ...

# %%
first_h1=soup.select('h1')[0].text
first_h1
# Out:
# 'Data Extraction from Unstructured PDFs'

# %%
#create  the all h1 as empty list
all_h1=[]
#select all the h1 tags of the soup
for element in soup.select('h2'):
    all_h1.append(element.text)
print(all_h1)
# Out:
# ['Introduction:', 'PyMuPDF:', 'Code:', 'Data Cleaning and Data Processing', 'Top Resources', '\n\n\n×\n\n']

# %%
sevent_p_text=soup.select('p')[7].text

# %%
print(sevent_p_text)
# Out:
# I have used the PyMuPDF library for this purpose. This library provided many applications such as extracting images from PDF, extracting texts from different shapes, making annotations, draw a bounded box around the texts along with the features of libraries like PyPDF2.

# %%
top_item=[]

# %%
products=soup.select('div.thumbnail')
for elem in products:
    title=elem.select('h4>a.title')[0].text
    review_label=elem.select('div.ratings')[0].text
    info={
        'title':title.strip(),
        'review': review_label.strip()
    }
    top_item.append(info)
print(top_item)
# Out:
# []

# %%
all_products=soup.select("div.thumbnail")
for product in products:
    print('work on product here')
keys=all_products[0].keys()
with open("product.csv",'w',newline="") as output_file:
    dict_writer=csv.DictWriter()
dict_writer.writerrow(all_products)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-20-f7d29fae27e2> in <module>
#       2 for product in products:
#       3     print('work on product here')
# ----> 4 keys=all_products[0].keys()
#       5 with open("product.csv",'w',newline="") as output_file:
#       6     dict_writer=csv.DictWriter()
#
# IndexError: list index out of range

# %%
all_products
# Out:
# []
