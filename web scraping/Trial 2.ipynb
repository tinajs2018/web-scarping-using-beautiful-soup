# %%
import pandas as pd

# %%
from  bs4 import BeautifulSoup

# %%
import urllib.request

# %%
from urllib.request import urlopen, Request

# %%
wiki= "https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=1"
html=urlopen(wiki)

# %%
bs= BeautifulSoup(html,'lxml')
bs
# Out:
# <!--default_base.blade.php--><!DOCTYPE html>
# <html lang="en">
# <head>
# <title>Search | The Star</title>
# <link href="https://cdn.thestar.com.my/Themes/img/favicon.ico" rel="icon" type="image/png"/>
# <!--START: common.blade.php-->
# <meta content="text/html;charset=utf-8" http-equiv="Content-Type"/><script type="text/javascript">(window.NREUM||(NREUM={})).init={privacy:{cookies_enabled:false},ajax:{deny_list:["bam-cell.nr-data.net"]}};(window.NREUM||(NREUM={})).loader_config={xpid:"VgIEVF9QChADU1hQAAUGUFc=",licenseKey:"ef8b08f3e1",applicationID:"379274163"};window.NREUM||(NREUM={}),__nr_require=function(t,e,n){function r(n){if(!e[n]){var i=e[n]={exports:{}};t[n][0].call(i.exports,function(e){var i=t[n][1][e];return r(i||e)},i,i.exports)}return e[n].exports}if("function"==typeof __nr_require)return __nr_require;for(var i=0;i<n.length;i++)r(n[i]);return r}({1:[function(t,e,n){function r(t){try{s.console&&console.log(t)}catch(e){}}var i,o=t("ee"),a=t(26),s={};try{i=localStorage.getItem("__nr_flags").split(","),console&&"function"==typeof console.log&&(s.console=!0,i.indexOf("dev")!==-1&&(s.dev=!0),i.indexOf("nr_dev")!==-1&&(s.nrDev=!0))}catch(c){}s.nrDev&&o.on("internal-error",function(t){r(t.stack)}),s.dev&&o.on("fn-err",function(t,e,n){r(n.stack)}),s.dev&&(r("NR AGENT IN DEVELOPMENT MODE"),r("flags: "+a(s,function(t,e){return t}).join(", ")))},{}],2:[function(t,e,n){function r(t,e,n,r,s){try{p?p-=1:i(s||new UncaughtException(t,e,n),!0)}catch(f){try{o("ierr",[f,c.now(),!0])}catch(d){}}return"function"==typeof u&&u.apply(this,a(arguments))}function UncaughtException(t,e,n){this.message=t||"Uncaught error with no additional information",this.sourceURL=e,this.line=n}function i(t,e){var n=e?null:c.now();o("err",[t,n])}var o=t("handle"),a=t(27),s=t("ee"),c=t("loader"),f=t("gos"),u=window.onerror,d=!1,l="nr@seenError";if(!c.disabled){var p=0;c.features.err=!0,t(1),window.onerror=r;try{throw new Error}catch(h){"stack"in h&&(t(10),t(9),"addEventListener"in window&&t(6),c.xhrWrappable&&t(11),d=!0)}s.on("fn-start",function(t,e,n){d&&(p+=1)}),s.on("fn-err",function(t,e,n){d&&!n[l]&&(f(n,l,function(){return!0}),this.thrown=!0,i(n))}),s.on("fn-end",function(){d&&!this.thrown&&p>0&&(p-=1)}),s.on("internal-error",function(t){o("ierr",[t,c.now(),!0])})}},{}],3:[function(t,e,n){var r=t("loader");r.disabled||(r.features.ins=!0)},{}],4:[function(t,e,n){function r(){var t=new PerformanceObserver(function(t,e){var n=t.getEntries();s(m,[n])});try{t.observe({entryTypes:["resource"]})}catch(e){}}function i(t){if(s(m,[window.performance.getEntriesByType(w)]),window.performance["c"+d])try{window.performance[p](h,i,!1)}catch(t){}else try{window.performance[p]("webkit"+h,i,!1)}catch(t){}}function o(t){}if(window.performance&&window.performance.timing&&window.performance.getEntriesByType){var a=t("ee"),s=t("handle"),c=t(10),f=t(9),u=t(5),d="learResourceTimings",l="addEventListener",p="removeEventListener",h="resourcetimingbufferfull",m="bstResource",w="resource",v="-start",g="-end",y="fn"+v,x="fn"+g,b="bstTimer",E="pushState",R=t("loader");if(!R.disabled){R.features.stn=!0,t(8),"addEventListener"in window&&t(6);var O=NREUM.o.EV;a.on(y,function(t,e){var n=t[0];n instanceof O&&(this.bstStart=R.now())}),a.on(x,function(t,e){var n=t[0];n instanceof O&&s("bst",[n,e,this.bstStart,R.now()])}),c.on(y,function(t,e,n){this.bstStart=R.now(),this.bstType=n}),c.on(x,function(t,e){s(b,[e,this.bstStart,R.now(),this.bstType])}),f.on(y,function(){this.bstStart=R.now()}),f.on(x,function(t,e){s(b,[e,this.bstStart,R.now(),"requestAnimationFrame"])}),a.on(E+v,function(t){this.time=R.now(),this.startPath=location.pathname+location.hash}),a.on(E+g,function(t){s("bstHist",[location.pathname+location.hash,this.startPath,this.time])}),u()?(s(m,[window.performance.getEntriesByType("resource")]),r()):l in window.performance&&(window.performance["c"+d]?window.performance[l](h,i,!1):window.performance[l]("webkit"+h,i,!1)),document[l]("scroll",o,{passive:!0}),document[l]("keypress",o,!1),document[l]("click",o,!1)}}},{}],5:[function(t,e,n){e.exports=function(){return"PerformanceObserver"in window&&"function"==typeof window.PerformanceObserver}},{}],6:[function(t,e,n){function r(t){for(var e=t;e&&!e.hasOwnProperty(u); ...
# <meta content="index,follow" name="ROBOTS"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <!--END: common.blade.php-->
# <!--START: index.blade.php -->
# <script type="application/ld+json">
# {
# "@context": "http://schema.org",
# "@type": "WebPage",
# "headline": "Search | The Star",
# "articleSection": "search?pgno=1&q=HIV&qrec=10&qsort=oldest&qstockcode=",
# "creator": "The Star Online",
# "thumbnailUrl": "https://cdn.thestar.com.my/Themes/img/newTsol_logo_socmedia.png",
# "dateCreated": "2019-07-29T14:48:52Z",
# "url": "http://www.thestar.com.my/search?pgno=1&q=HIV&qrec=10&qsort=oldest&qstockcode=",
# "keywords":[""]
# }</script>
# <meta content="Search" name="page_type"/>
# <meta content="pgno=1&amp;q=HIV&amp;qrec=10&amp;qsort=oldest&amp;qstockcode=" name="page_search_query"/>
# <meta content="" name="page_category"/>
# <meta content="" name="description"/>
# <link href="http://www.thestar.com.my/" rel="canonical"/>
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="@staronline" name="twitter:site"/>
# <meta content="" property="og:description"/>
# <meta content="" name="twitter:description"/>
# <meta content="Search | The Star" property="og:title"/>
# <meta content="https://cdn.thestar.com.my/Themes/img/newTsol_logo_socmedia.png" name="twitter:image:src"/>
# <meta content="https://cdn.thestar.com.my/Themes/img/newTsol_logo_socmedia.png" property="og:image"/>
# <meta content="https://www.thestar.com.my/search?pgno=1&amp;q=HIV&amp;qrec=10&amp;qsort=oldest&amp;qstockcode=" property="og:url"/>
# <meta content="website" property="og:type"/>
# <meta content='{"guid": "186", "byline": "NA", "image_url": "https://cdn.thestar.com.my/Themes/img/newTsol_logo_socmedia.png", "contain_video": false, "is_premium": false}' name="parsely-metadata"/>
# <meta content="unsafe-url" name="referrer"/>
# <meta content="frontpage" name="cXenseParse:pageclass"/>
# <meta content="free" name="cXenseParse:smg-accesstype"/>
# <meta content="121120175250633" property="fb:app_id"/>
# <!--END: index.blade.php -->
# <!-- CSRF Token -->
# <meta content="W8M2ijYyxllwO0zsqqDGYN3Rxckl0JewSBmRSWyw" name="csrf-token"/>
# <!-- Global Header scripts -->
# <!-- Start Header Script -->
# <!-- Anti-flicker snippet (recommended)  -->
# <style>.async-hide { opacity: 0 !important} </style>
# <script>(function(a,s,y,n,c,h,i,d,e){s.className+=' '+y;h.start=1*new Date;
# h.end=i=function(){s.className=s.className.replace(RegExp(' ?'+y),'')};
# (a[n]=a[n]||[]).hide=h;setTimeout(function(){i();h.end=null},c);h.timeout=c;
# })(window,document.documentElement,'async-hide','dataLayer',4000,
# {'GTM-PVM4TH':true});</script>
# <meta content="app-id=428184176" name="apple-itunes-app"/>
# <link href="https://cdn.thestar.com.my/Themes/css/bootstrap.min.css" rel="stylesheet" type="text/css"/>
# <link href="https://fonts.googleapis.com/css?family=Lato:300,300i,400,400i,700,700i,900,900i&amp;display=swap" rel="stylesheet" type="text/css"/>
# <link href="https://cdn.thestar.com.my/Themes/css/tsol2019_pw.css?v=20210907" rel="stylesheet" type="text/css"/>
# <link href="https://cdn.thestar.com.my/Themes/css/story2017.min.css?v=20211012" rel="stylesheet" type="text/css"/>
# <link href="https://cdn.thestar.com.my/Themes/css/info.css" rel="stylesheet" type="text/css"/>
# <link href="https://cdn.thestar.com.my/Themes/css/bookmark.min.css?v=20201123" rel="stylesheet" type="text/css"/>
# <link href="https://cdn.thestar.com.my/Themes/css/main.css?v=20210323" rel="stylesheet" type="text/css"/>
# <link href="https://cdn.thestar.com.my/Themes/css/promo.css" rel="stylesheet" type="text/css"/>
# <link href="https://cdn.thestar.com.my/Themes/css/responsive.min.css" media="only screen and (max-width:767px)" rel="stylesheet" type="text/css"/>
# <link href="https://cdn.thestar.com.my/Themes/css/stock.search.min.css" rel="stylesheet" type="text/css"/>
# <link href="https://cdn.thestar.com.my/Themes/css/font-awesome.min.css" rel="stylesheet" type="text/css"/>
# <link href="https://cdn.thestar.com.my/GlobalBar/css/global-bar.min.css" rel="stylesheet" type="text/css"/>
# <link href="https://cdn.thestar.com.my/Components/Audio/audio.css" rel="stylesheet" type="text/css"/>
# <link href="https://cdn.thestar.com.my/Themes/css/owl.carousel.min.css" rel="stylesheet" type="text/css"/>
# <link href="https://cdn.thestar.com.my/Themes/css/style.min.css?v=20201123" rel="stylesheet" type="text/css"/>
# <!-- hide globalbar for tablet -->
# <style>@media screen and (min-width: 768px) and (max-width: 1024px){
# #thestar-global-bar { display: none; }
# body { padding-top: 0 !important; }
# #navbar-main.affix { top: 0 !important; }
# }</style>
# <style>
# .sassize{--breakpoint:desktop}@media all and (max-width:991px){.sassize{--breakpoint:tablet}}@media all and (max-width:767px){.sassize{--breakpoint:mobile}}
# img[src$="default.gif"] { display: none;}
# img[src^="https://content.thestar.com.my/smg/settag/name=lotame/tags="] {display:none;}
# .masthead {
#   background: url(https://cdn.thestar.com.my/Widgets/Masthead/2021/CNY.png) no-repeat -75px 0 transparent;
# }
# .masthead-2 {
#     position: absolute;
#     width: 250px;
#     left: 41%;
#     right: 41%;
#     top: 12px;
# }
# .anniv-special{
# 	display:none;
# }
# @media only screen and (max-width: 991px) {
#     /*50 years special*/
#     .anniv-special{
# 	display:block;
# 	margin:0 auto;
# 	text-align:center;
#     }
#    .anniv-special img{
#         height: auto;
#         width: 200px;
#         margin-top: 12px;
#         margin-bottom: 12px;
#     }
# }
# </style>
# <script async="" src="https://scdn.cxense.com/cx.cce.js" type="text/javascript"></script>
# <script src="//ajax.googleapis.com/ajax/libs/jquery/3.1.1/jquery.min.js"></script>
# <script src="https://cdn.thestar.com.my/Themes/js/parsely-onload.min.js"></script>
# <!-- HTML5 Shim and Respond.js IE8 support of HTML5 elements and media queries -->
# <!-- WARNING: Respond.js doesn't work if you view the page via file:// -->
# <!--[if lt IE 9]>
# <script src="https://oss.maxcdn.com/libs/html5shiv/3.7.0/html5shiv.js"></script>
# <script src="https://oss.maxcdn.com/libs/respond.js/1.4.2/respond.min.js"></script>
# <![endif]-->
# <script src="https://cdnjs.cloudflare.com/ajax/libs/URI.js/1.18.10/URI.min.js"></script>
# <script src="https://cdnjs.cloudflare.com/ajax/libs/moment.js/2.18.1/moment.min.js"></script>
# <script src="https://cdnjs.cloudflare.com/ajax/libs/postscribe/2.0.8/postscribe.min.js"></script>
# <script src="https://cdn.thestar.com.my/Themes/js/js.cookie.js"></script>
# <script src="https://cdn.thestar.com.my/Themes/js/jquery.dotdotdot.min.js"></script>
# <script src="https://cdn.jsdelivr.net/npm/vue@2.5.12/dist/vue.min.js"></script>
# <script src="https://cdnjs.cloudflare.com/ajax/libs/axios/0.19.0/axios.min.js"></script>
# <script src="https://cdn.thestar.com.my/Themes/js/Main.min.js"></script>
# <script src="https://cdn.thestar.com.my/Themes/js/widget_mixin.js"></script>
# <script>var my_jquery = jQuery;</script>
# <script>jQuery = my_jquery;</script>
# <script type="text/javascript">
# var pageType = jQuery('meta[name=pageType]').attr("content");
# if(pageType == "article"){
# var cX = window.cX = window.cX || {}; cX.callQueue = cX.callQueue || [];
# var cxenseRandom = jQuery('meta[name=cxenseRandom]').attr("content");
# cX.CCE = cX.CCE || {}; cX.CCE.callQueue = cX.CCE.callQueue || [];
# }
# else{ var cX = cX || {}; cX.callQueue = cX.callQueue || []; }
# </script>
# <script src="https://cdn.thestar.com.my/Themes/js/slick.min.js"></script>
# <script defer="" src="https://cdn.thestar.com.my/Themes/js/jquery.unveil.js" type="text/javascript"></script>
# <script src="//connect.facebook.net/en_US/all.js" type="text/javascript"></script>
# <script>
# FB.init({
#   appId: '388467334571811',
#   version: 'v2.9',
#   status: true, // check login status
#   cookie: true, // enable cookies to allow the server to access the session
#   xfbml: true  // parse XFBML
# });
#
# var KICKER_FREE_MARKUP='<span class="labels labels--free" data-toggle="tooltip" title="" data-original-title="This is a Free article"><i class="fa fa-unlock"></i></span>'
# var KICKER_PREMIUM_MARKUP='<span class="biz-icon" data-toggle="tooltip" title="" id="sbp-tip" data-original-title="Premium">Premium</span>';
# var KICKER_LOCK_MARKUP='<span class="biz-icon" data-toggle="tooltip" title="" id="sbp-tip" data-original-title="To unlock the article, click on the headline and log in with your StarBiz Premium account or select a membership to join." aria-describedby="tooltip489695">StarBiz Premium</span>';
# var KICKER_UNLOCK_MARKUP='<span class="biz-icon"><i class="fa fa-unlock"></i></span>';
# </script>
# <!-- Cx FB user linking script begin -->
# <script type="text/javascript">
#   cX.callQueue.push(['invoke', function() {
#     function checkFBLogin() {
#      if (window.FB && typeof FB.getLoginStatus === 'function') {
#
#         FB.getLoginStatus(function(response) {
#           if (response.status === 'connected') {
#             // Read the FaceBook user ID
#             var fbUserId = response.authResponse.userID;
#             // Map the Facebook user ID to the Cxense user ID
#             var persistedQueryId = '925dff57b9697543df967d4cbe9a38a074458905';
#             var apiUrl = 'https://api.cxense.com/profile/user/external/link/update?callback={{callback}}'
#               + '&persisted=' + encodeURIComponent(persistedQueryId)
#               + '&json=' + encodeURIComponent(cX.JSON.stringify({ id: fbUserId, cxid: cX.getUserId() }));
#             cX.jsonpRequest(apiUrl, function (data) { /* If wanted, verify success here*/ });
#           } else {
#             setTimeout(checkFBLogin, 1000);
#           }
#         });
#
#       } else {
#         setTimeout(checkFBLogin, 1000);
#       }
#     }
#     checkFBLogin();
#   }]);
# </script>
# <!-- Cx FB user linking script end -->
# <script src="https://cdn.thestar.com.my/Themes/js/owl.carousel.min.js"></script>
# <script src="https://cdn.thestar.com.my/Themes/js/parsely-onload.min.js"></script>
# <script src="https://cdn.thestar.com.my/Themes/js/mediatag.min.js"></script>
# <script src="https://cdn.thestar.com.my/Themes/js/mediahelper.min.js"></script>
# <link href="https://cdn.thestar.com.my/Themes/img/touch-icon-precomposed.png" rel="apple-touch-icon" sizes="57x57"/>
# <link href="https://cdn.thestar.com.my/Themes/img/touch-icon-iphone.png" rel="apple-touch-icon" sizes="114x114"/>
# <link href="https://cdn.thestar.com.my/Themes/img/touch-icon-120x120.png" rel="apple-touch-icon" sizes="120x120"/>
# <link href="https://cdn.thestar.com.my/Themes/img/touch-icon-ipad.png" rel="apple-touch-icon" sizes="152x152"/>
# <link href="https://cdn.thestar.com.my/Themes/img/touch-icon-iphone-retina.png" rel="apple-touch-icon" sizes="167x167"/>
# <link href="https://cdn.thestar.com.my/Themes/img/touch-icon-ipad-retina.png" rel="apple-touch-icon" sizes="180x180"/>
# <link href="https://cdn.thestar.com.my/Themes/img/touch-icon-192x192.png" rel="apple-touch-icon" sizes="192x192"/>
# <link href="https://cdn.thestar.com.my/Themes/css/widgettop.min.css" rel="stylesheet" type="text/css"/>
# <script src="https://cdn.thestar.com.my/Themes/js/widgettop.min.js"></script>
# <script src="//s7.addthis.com/js/300/addthis_widget.js#pubid=ra-5dfaeb0face4ad17" type="text/javascript"></script>
# <script data-obct="" type="text/javascript">
#     /** DO NOT MODIFY THIS CODE**/
#     !function(_window, _document) {
#       var OB_ADV_ID='00a149fe9401c432f57edaa96ee66b065d';
#       if (_window.obApi) {var toArray = function(object) {return Object.prototype.toString.call(object) === '[object Array]' ? object : [object];};_window.obApi.marketerId = toArray(_window.obApi.marketerId).concat(toArray(OB_ADV_ID));return;}
#       var api = _window.obApi = function() {api.dispatch ? api.dispatch.apply(api, arguments) : api.queue.push(arguments);};api.version = '1.1';api.loaded = true;api.marketerId = OB_ADV_ID;api.queue = [];var tag = _document.createElement('script');tag.async = true;tag.src = '//amplify.outbrain.com/cp/obtp.js';tag.type = 'text/javascript';var script = _document.getElementsByTagName('script')[0];script.parentNode.insertBefore(tag, script);}(window, document);
# obApi('track', 'PAGE_VIEW');
# </script>
# <noscript><img src="//amplifypixel.outbrain.com/pixel?mid=00a149fe9401c432f57edaa96ee66b065d"/></noscript>
# <!-- Start Deco masthead -->
# <script type="text/javascript">
# jQuery(document).ready(function(){
# var checkDeco = new Date();
# var decoStart = new Date("March 10, 2021 00:00:00");
# var decoEnd = new Date("December 31, 2021 23:59:59");
# if (checkDeco.getTime() > decoStart.getTime() && checkDeco.getTime() < decoEnd.getTime()){
# //This is for regular festival masthead
# //$("#page-header > div >div").attr("class", "container masthead");
#
# }
# });
# </script>
# <!-- End Deco masthead -->
# <script>var rmad = false;</script>
# <!-- End Header Script --> <!-- theme includes js_extra.blade.php -->
# <script type="text/javascript">
# var viewid = Math.round(Math.random() * 100000000000);
# function sasiajserver(size,position){
# var SAS = JSON.parse(jQuery('meta[name=SAS]').attr("content"));
# var rdm2 = Math.round(Math.random() * 100000000000);
# return "https://content.thestar.com.my/smg/jserver/viewid=" + viewid +
#     "/random=" + rdm2 +
#     "/network=SMG/site=TSOL" +
#     "/area=" + SAS.area +
#     "/pagetype=" + SAS.pagetype +
#     "/platform=" + sascalcsize() +
#     "/size=" + size +
#     "/position=" + position;
# }
# function sascalcsize(){var b=window.getComputedStyle(document.querySelector(".sassize"));var a=b.getPropertyValue("--breakpoint");return a};
# </script>
# <!-- Admiral -->
# <script>
#     window.admiral = window.admiral || function() {(admiral.q = admiral.q || []).push(arguments)};
#              window.admiral("targeting", "set", "MyStarMember", "false");
#          if(pageType == "article"){
#                 var daxsubscriber = false;
#           }
#
#     if(pageType == "article"){
#         window.admiral("after", "measure.detected", function(user) {
#
#         let eventLabel;
#
#         if (user.adblocking) {
#
#           eventLabel = "blocked";
#
#         }
#
#         if (user.whitelisted) {
#
#           eventLabel = "whitelisted";
#
#         }
#
#
#
#         if (eventLabel) {
#
#           ga("send", "event", "Admiral", "pageview", eventLabel, {
#
#             nonInteraction: true
#
#           });
#
#             }
#
#         });
#     }
# </script>
# <!-- End Admiral -->
# <script>
# // show or hide login button
# var rmad = false;
# var isLogin = false;
#
# tkValid = [false,false];
# if (tkValid[0] === true) {
#     rmad = tkValid[1];
#     isLogin = true;
# } else {
#     isLogin = false;
# }
#
# jQuery(document).ready(function() {
#   if (tkValid[0] === true) {
#     jQuery('.btn_login').hide();
#     jQuery('.login_menu').show();
#     jQuery('.m-login-menu').show();
#     jQuery('.m-login-button').attr("style", "display: none !important"); // Override css
# } else {
#     jQuery('.btn_login').show();
#     jQuery('.login_menu').hide();
#     jQuery('.m-login-button').show();
#     jQuery('.m-login-menu').hide();
# }
# });
# </script> <!-- resources common css_includes.blade.php -->
# <!-- theme includes css_includes.blade.php --> <!-- Widget CSS links -->
# <!-- Page Header scripts -->
# <script>
#         window.Laravel = {"csrfToken":"W8M2ijYyxllwO0zsqqDGYN3Rxckl0JewSBmRSWyw"}
#         var IMAGE_URL = 'https://apicms.thestar.com.my/';
#     </script>
# </head>
# <body>
# <div class="sassize"></div>
# <!-- Main THEME Content -->
# <!-- page content -->
# <div class="widgettop" id="widgettop" style="display:none;">
# <div class="flex-container">
# <div class="firinfo"></div>
# <div class="close">
# <img id="closeButton" src="https://cdn.thestar.com.my/Themes/img/close.png"/>
# </div>
# </div>
# </div> <!-- HEADER OF THEME -->
# <!-- header_menu -->
# <style type="text/css">
#   @media  screen and (max-width: 768px){
#     a#hllogin:hover {
#       background-color: #EEEEEE !important;
#     }
#   }
#   .navbar-header{
#       margin-right: 0 !important;
#   }
# </style>
# <header id="page-header">
# <div class="branding">
# <div class="container">
# <a class="navbar-brand brand-prime" data-content-id="https://www.thestar.com.my" data-content-title="The Star Online" data-content-type="Navigation" data-list-type="Header" href="/">
# <svg aria-label="the star online" class="icon" height="55" role="img" width="164">
# <image border="0" height="55" src="https://cdn.thestar.com.my/Themes/img/logo-tsol-logo.png" width="164" xlink:href="https://cdn.thestar.com.my/Themes/img/logo-tsol-full.svg"/>
# </svg>
# </a>
# <ul class="nav social-branding right">
# <!--                <li>
#                     <a href="https://newsstand.thestar.com.my/epaper/" target="_blank" class="epaper"
#                        data-list-type="Header"
#                        data-content-type="App Download"
#                        data-content-title="ePaper"
#                        data-content-id="https://newsstand.thestar.com.my/epaper/ ">
#                         <i class="icon sprite-icon"></i> The Star ePaper
#                     </a>
#                 </li>-->
# <li class="dropdown dropdown--subscribe top-bar">
# <a class="btn--subscribe" data-content-id="https://www.thestar.com.my/subscription" data-content-title="Subscription" data-content-type="Navigation" data-list-type="Header" href="/subscription">Subscriptions</a>
# </li>
# <li class="btn-login" id="btn_login">
# <a class="login" data-content-id="https://sso.thestar.com.my/?lng=en&amp;channel=1&amp;ru=HNQ8Auw31qgZZU47ZjHUhHKJStkK3H51/pPcFdJ1gQ9cFgPiSalasDvF6DeumuZw8pseQRWJP/yR0PBhFpgeZp4+UVtRvpLRHWwfdJGUo5A=" data-content-title="Log In" data-content-type="Outbound Referral" data-list-type="Header" href="https://sso.thestar.com.my/?lng=en&amp;channel=1&amp;ru=HNQ8Auw31qgZZU47ZjHUhHKJStkK3H51/pPcFdJ1gQ9cFgPiSalasDvF6DeumuZw8pseQRWJP/yR0PBhFpgeZp4+UVtRvpLRHWwfdJGUo5A=">
#                         Log In
#                      </a>
# </li>
# <li class="dropdown top-bar" id="login_menu" style="display:none;">
# <a class="log-in-light" id="hllogin"><i class="icon sprite-icon"></i></a>
# <ul class="dropdown-menu log-in 123">
# <li>
# <a data-content-title="https://login.thestar.com.my/accountinfo/profile.aspx" data-content-type="Manage Profile" data-list-type="Profile Management" href="https://login.thestar.com.my/accountinfo/profile.aspx" target="_blank">Manage Profile
#                                 </a>
# </li>
# <li>
# <a data-content-title="https://login.thestar.com.my/accountinfo/changepassword.aspx" data-content-type="Change Password" data-list-type="Profile Management" href="https://login.thestar.com.my/accountinfo/changepassword.aspx" target="_blank">Change Password
#                                 </a>
# </li>
# <li>
# <a data-content-title="https://login.thestar.com.my/accountinfo/sessions.aspx" data-content-type="Manage Logins" data-list-type="Profile Management" href="https://login.thestar.com.my/accountinfo/sessions.aspx" target="_blank">Manage Logins
#                                 </a>
# </li>
# <li style="border-top:1px solid #d6d6d6">
# <a data-content-title="https://login.thestar.com.my/accountinfo/subscriptioninfo.aspx" data-content-type="Manage Subscription" data-list-type="Profile Management" href="https://login.thestar.com.my/accountinfo/subscriptioninfo.aspx" target="_blank">Manage Subscription
#                                 </a>
# </li>
# <li>
# <a data-content-title="https://login.thestar.com.my/accountinfo/transhistory.aspx" data-content-type="Transaction History" data-list-type="Profile Management" href="https://login.thestar.com.my/accountinfo/transhistory.aspx" target="_blank">Transaction History
#                                 </a>
# </li>
# <li>
# <a data-content-title="https://login.thestar.com.my/accountinfo/billing.aspx" data-content-type="Manage Billing Info" data-list-type="Profile Management" href="https://login.thestar.com.my/accountinfo/billing.aspx" target="_blank">Manage Billing Info
#                                 </a>
# </li>
# <li style="border-top:1px solid #d6d6d6">
# <a data-content-title="https://www.thestar.com.my/foryou/edit" data-content-type="Manage For You" data-list-type="Profile Management" href="https://www.thestar.com.my/foryou/edit">Manage For You
#                                 </a>
# </li>
# <li style="border-bottom:1px solid #d6d6d6">
# <a data-content-title="https://www.thestar.com.my/saved-articles" data-content-type="Manage Bookmarks" data-list-type="Profile Management" href="https://www.thestar.com.my/saved-articles">Manage Bookmarks
#                                 </a>
# </li>
# <li>
# <a data-content-title="https://www.thestar.com.my/subscribe" data-content-type="Package &amp; Pricing" data-list-type="Profile Management" href="https://www.thestar.com.my/subscribe">Package &amp; Pricing
#                                 </a>
# </li>
# <li>
# <a data-content-title="https://www.thestar.com.my/faqs/" data-content-type="FAQs" data-list-type="Profile Management" href="https://www.thestar.com.my/faqs/">FAQs
#                                 </a>
# </li>
# <li class="log-out">
# <a data-content-title="https://www.thestar.com.my" data-content-type="Log Out" data-list-type="Profile Management" href="#" onclick="logout();">Log Out
#                                 </a>
# </li>
# </ul>
# </li>
# </ul>
# </div>
# </div>
# <nav class="navbar navbar-custom" data-offset-top="197" data-spy="affix" id="navbar-main">
# <div class="container">
# <div class="navbar-header">
# <button class="navbar-toggle left" data-target="#tsolmobar" data-toggle="collapse" type="button">
# <span class="sr-only">Toggle navigation</span>
# <span class="icon-bar"></span>
# <span class="icon-bar"></span>
# <span class="icon-bar"></span>
# <i class="icon-x fa fa-times"></i>
# </button>
# <a class="navbar-brand brand-mobile left" data-content-id="https://www.thestar.com.my" data-content-title="The Star Online" data-content-type="Navigation" data-list-type="Header" href="/">
# <svg aria-label="the star online" class="icon" height="26" role="img" width="70">
# <image border="0" height="26" src="https://cdn.thestar.com.my/Themes/img/logo-tsol-mobile.png" width="70" xlink:href="https://cdn.thestar.com.my/Themes/img/logo-tsol-full.svg" xmlns:xlink="http://www.w3.org/1999/xlink"/>
# </svg>
# </a>
# </div>
# <div id="tsolnavbar">
# <ul class="nav navbar-nav navbar-left">
# <li class="show-sd">
# <button aria-expanded="false" class="mega-nav-toggle navbar-toggle collapsed hidden-xs" data-target="#bs-example-navbar-collapse-1" data-toggle="collapse" type="button">
# <span class="sr-only">Toggle navigation</span>
# <span class="icon-bar"></span>
# <span class="icon-bar"></span>
# <span class="icon-bar"></span>
# <i class="icon-x fa fa-times"></i>
# </button>
# </li>
# <li>
# <a class="home-light" data-content-id="https://www.thestar.com.my" data-content-title="Home" data-content-type="Navigation" data-list-type="Header" href="/" id="navi-home" onclick="ga('send', 'event' , 'TSOL NAVI' , 'Standard' , '/Home/' ); " target="">
# <i class="icon sprite-icon"></i>
# </a>
# </li>
# <li class="dropdown">
# <a class="starplus" data-content-id="https://www.thestar.com.my/starplus" data-content-title="StarPlus" data-content-type="Navigation" data-list-type="Header" href="/starplus" id="navi-starplus" onclick="ga('send', 'event' , 'TSOL NAVI' , 'Standard' , '/StarPlus/' ); " target="">
#                     StarPlus
#                     </a>
# </li>
# <li class="dropdown">
# <a class="news" data-content-id="https://www.thestar.com.my/news" data-content-title="News" data-content-type="Navigation" data-list-type="Header" href="/news" id="navi-news" onclick="ga('send', 'event' , 'TSOL NAVI' , 'Standard' , '/News/' ); " target="">
#                     News
#                     </a>
# </li>
# <li class="dropdown">
# <a class="asean+" data-content-id="https://www.thestar.com.my/aseanplus" data-content-title="Asean+" data-content-type="Navigation" data-list-type="Header" href="/aseanplus" id="navi-asean+" onclick="ga('send', 'event' , 'TSOL NAVI' , 'Standard' , '/AseanPlus/' ); " target="">
#                     Asean+
#                     </a>
# </li>
# <li class="dropdown">
# <a class="business" data-content-id="https://www.thestar.com.my/business" data-content-title="Business" data-content-type="Navigation" data-list-type="Header" href="/business" id="navi-business" onclick="ga('send', 'event' , 'TSOL NAVI' , 'Standard' , '/Business/' ); " target="">
#                     Business
#                     </a>
# </li>
# <li class="dropdown">
# <a class="sport" data-content-id="https://www.thestar.com.my/sport" data-content-title="Sport" data-content-type="Navigation" data-list-type="Header" href="/sport" id="navi-sport" onclick="ga('send', 'event' , 'TSOL NAVI' , 'Standard' , '/Sport/' ); " target="">
#                     Sport
#                     </a>
# </li>
# <li class="dropdown">
# <a class="metro" data-content-id="https://www.thestar.com.my/metro" data-content-title="Metro" data-content-type="Navigation" data-list-type="Header" href="/metro" id="navi-metro" onclick="ga('send', 'event' , 'TSOL NAVI' , 'Standard' , '/Metro/' ); " target="">
#                     Metro
#                     </a>
# </li>
# <li class="dropdown">
# <a class="lifestyle" data-content-id="https://www.thestar.com.my/lifestyle" data-content-title="Lifestyle" data-content-type="Navigation" data-list-type="Header" href="/lifestyle" id="navi-lifestyle" onclick="ga('send', 'event' , 'TSOL NAVI' , 'Standard' , '/Lifestyle/' ); " target="">
#                     Lifestyle
#                     </a>
# </li>
# <li class="dropdown">
# <a class="food" data-content-id="https://www.thestar.com.my/food" data-content-title="Food" data-content-type="Navigation" data-list-type="Header" href="/food" id="navi-food" onclick="ga('send', 'event' , 'TSOL NAVI' , 'Standard' , '/Food/' ); " target="">
#                     Food
#                     </a>
# </li>
# <li class="dropdown">
# <a class="tech" data-content-id="https://www.thestar.com.my/tech" data-content-title="Tech" data-content-type="Navigation" data-list-type="Header" href="/tech" id="navi-tech" onclick="ga('send', 'event' , 'TSOL NAVI' , 'Standard' , '/Tech/' ); " target="">
#                     Tech
#                     </a>
# </li>
# <li class="dropdown">
# <a class="education" data-content-id="https://www.thestar.com.my/education" data-content-title="Education" data-content-type="Navigation" data-list-type="Header" href="/education" id="navi-education" onclick="ga('send', 'event' , 'TSOL NAVI' , 'Standard' , '/Education/' ); " target="">
#                     Education
#                     </a>
# </li>
# <li class="dropdown">
# <a class="opinion" data-content-id="https://www.thestar.com.my/opinion" data-content-title="Opinion" data-content-type="Navigation" data-list-type="Header" href="/opinion" id="navi-opinion" onclick="ga('send', 'event' , 'TSOL NAVI' , 'Standard' , '/Opinion/' ); " target="">
#                     Opinion
#                     </a>
# </li>
# <li class="dropdown">
# <a class="videos" data-content-id="https://www.thestartv.com/c/news" data-content-title="Videos" data-content-type="Outbound Referral" data-list-type="Header" href="https://www.thestartv.com/c/news" id="navi-videos" onclick="ga('send', 'event' , 'TSOL NAVI' , 'Standard' , 'https://www.thestartv.com/c/news' ); " style="" target="_blank">
#                     Videos
#                     </a>
# </li>
# <li class="dropdown">
# <a class="photos" data-content-id="https://www.thestar.com.my/photos" data-content-title="Photos" data-content-type="Navigation" data-list-type="Header" href="/photos" id="navi-photos" onclick="ga('send', 'event' , 'TSOL NAVI' , 'Standard' , '/Photos/' ); " target="">
#                     Photos
#                     </a>
# </li>
# <li class="dropdown">
# <a class="starpicks" data-content-id="https://www.thestar.com.my/starpicks" data-content-title="StarPicks" data-content-type="Navigation" data-list-type="Header" href="/starpicks" id="navi-starpicks" onclick="ga('send', 'event' , 'TSOL NAVI' , 'Standard' , '/Starpicks/' ); " target="">
#                     StarPicks
#                     </a>
# </li>
# </ul>
# </div>
# <ul class="nav navbar-nav navbar-right">
# <li class="hidden-lg dropdown dropdown--subscribe">
# <a aria-expanded="false" class="btn--subscribe dropdown-toggle" data-prokeyscachednode="false" onclick="toggleSubDrop()" role="button">Subscriptions</a>
# <ul class="dropdown-menu" id="subDrop" style="display: none;">
# <li>
# <a data-content-id="https://www.thestar.com.my/subscribe" data-content-title="The Star Digital Access" data-content-type="Navigation" data-list-type="Header" href="/subscribe">The Star Digital Access</a>
# </li>
# <li>
# <a data-content-id="https://newsstand.thestar.com.my/" data-content-title="Newsstand" data-content-type="Outbound Referral" data-list-type="Header" href="https://newsstand.thestar.com.my/">Newsstand</a>
# </li>
# <li>
# <a data-content-id="https://www.thestar.com.my/sms-services" data-content-title="SMS Services" data-content-type="Navigation" data-list-type="Header" href="/sms-services">SMS Services</a>
# </li>
# </ul>
# </li>
# <li class="m-login-button hidden-md hidden-lg" id="btn_login" style="display: none;">
# <a class="login bttn bttn--log" data-content-id="https://sso.thestar.com.my/?lng=en&amp;channel=1&amp;ru=HNQ8Auw31qgZZU47ZjHUhHKJStkK3H51/pPcFdJ1gQ9cFgPiSalasDvF6DeumuZw8pseQRWJP/yR0PBhFpgeZp4+UVtRvpLRHWwfdJGUo5A=" data-content-title="Log In" data-content-type="Outbound Referral" data-list-type="Header" href="https://sso.thestar.com.my/?lng=en&amp;channel=1&amp;ru=HNQ8Auw31qgZZU47ZjHUhHKJStkK3H51/pPcFdJ1gQ9cFgPiSalasDvF6DeumuZw8pseQRWJP/yR0PBhFpgeZp4+UVtRvpLRHWwfdJGUo5A=">Log In
#                     </a>
# </li>
# <li class="m-login-menu hidden-md hidden-lg" id="login_menu" style="display:none;">
# <a class="log-in" id="hllogin" onclick="toggleDrop()"><i class="icon sprite-icon"></i></a>
# <ul class="dropdown-menu log-in" id="loginDrop" style="display: none;">
# <li>
# <a data-content-title="https://login.thestar.com.my/accountinfo/profile.aspx" data-content-type="Manage Profile" data-list-type="Profile Management" href="https://login.thestar.com.my/accountinfo/profile.aspx" target="_blank">Manage Profile
#                             </a>
# </li>
# <li>
# <a data-content-title="https://login.thestar.com.my/accountinfo/changepassword.aspx" data-content-type="Change Password" data-list-type="Profile Management" href="https://login.thestar.com.my/accountinfo/changepassword.aspx" target="_blank">Change Password
#                             </a>
# </li>
# <li>
# <a data-content-title="https://login.thestar.com.my/accountinfo/sessions.aspx" data-content-type="Manage Logins" data-list-type="Profile Management" href="https://login.thestar.com.my/accountinfo/sessions.aspx" target="_blank">Manage Logins
#                             </a>
# </li>
# <li style="border-top:1px solid #d6d6d6">
# <a data-content-title="https://login.thestar.com.my/accountinfo/subscriptioninfo.aspx" data-content-type="Manage Subscription" data-list-type="Profile Management" href="https://login.thestar.com.my/accountinfo/subscriptioninfo.aspx" target="_blank">Manage Subscription
#                             </a>
# </li>
# <li>
# <a data-content-title="https://login.thestar.com.my/accountinfo/transhistory.aspx" data-content-type="Transaction History" data-list-type="Profile Management" href="https://login.thestar.com.my/accountinfo/transhistory.aspx" target="_blank">Transaction History
#                             </a>
# </li>
# <li>
# <a data-content-title="https://login.thestar.com.my/accountinfo/billing.aspx" data-content-type="Manage Billing Info" data-list-type="Profile Management" href="https://login.thestar.com.my/accountinfo/billing.aspx" target="_blank">Manage Billing Info
#                             </a>
# </li>
# <li style="border-top:1px solid #d6d6d6">
# <a data-content-title="https://www.thestar.com.my/foryou/edit" data-content-type="Manage For You" data-list-type="Profile Management" href="https://www.thestar.com.my/foryou/edit">Manage For You
#                             </a>
# </li>
# <li style="border-bottom:1px solid #d6d6d6">
# <a data-content-title="https://www.thestar.com.my/saved-articles" data-content-type="Manage Bookmarks" data-list-type="Profile Management" href="https://www.thestar.com.my/saved-articles">Manage Bookmarks
#                             </a>
# </li>
# <li>
# <a data-content-title="https://www.thestar.com.my/subscribe" data-content-type="Package &amp; Pricing" data-list-type="Profile Management" href="https://www.thestar.com.my/subscribe">Package &amp; Pricing
#                             </a>
# </li>
# <li>
# <a data-content-title="https://www.thestar.com.my/faqs/" data-content-type="FAQs" data-list-type="Profile Management" href="https://www.thestar.com.my/faqs/">FAQs
#                             </a>
# </li>
# <li class="log-out">
# <a data-content-title="https://www.thestar.com.my" data-content-type="Log Out" data-list-type="Profile Management" href="#" onclick="logout();">Log Out
#                             </a>
# </li>
# </ul>
# </li>
# </ul>
# </div>
# <div aria-expanded="true" class="navi-primary-mobile removeRubberEffect navbar-collapse collapse" id="tsolmobar" style="position: fixed;">
# <ul class="mobile-panel">
# <li class="dropdown"> </li>
# <li>
# <div class="navigation-title">
# <div class="container searchbardiv">
# <form id="searchform2" method="post" role="search">
# <div class="input-group">
# <input class="form-control" id="qTextBox2" onkeypress="searchKeyPress(event, 'btnSearch2' ); " placeholder="What are you looking for?" type="text"/>
# <div id="qStockCodeHolder">
# <input id="qStockCodeVal2" type="hidden" value=""/>
# </div>
# <div class="input-group-btn">
# <input class="btn btn-default" id="btnSearch2" onclick="jQuery('#qTextBox2').addClass('loadinggif'); post('/search/', { q: document.getElementById('qTextBox2').value, qsort: 'newest', qrec: '10', qstockcode: document.getElementById('qStockCodeVal2').value }, 'get');ga('send', 'event', 'TSOL NAVI', 'Extra-Panel', 'Search Button'); " style="font-weight: bold" type="button" value="Search"/>
# <a class="btn btn-default adv-search-link" data-content-id="https://www.thestar.com.my/search/?adv=1" data-content-title="Advance Search" data-content-type="Navigation" data-list-type="Header" href="/search?adv=1" onclick="ga('send', 'event' , 'TSOL NAVI' , 'Extra-Panel' , 'Advance Search' ); " onmousedown="searchAdvanceClick(this,'qTextBox2')" style="font-weight: 900"><i class="icon sprite-icon plus"></i>
# </a>
# </div>
# </div>
# </form>
# </div>
# </div>
# </li>
# <li>
# <a class="navigation-title" data-content-id="https://www.thestar.com.my" data-content-title="Home" data-content-type="Navigation" data-list-type="Header" href="/" onclick="ga('send', 'event', 'TSOL NAVI', 'Mobile', '/Home/');" target="_self">Home
#                     </a>
# </li>
# <li class="navigation-section">
# <a class="navigation-title" data-content-id="https://www.thestar.com.my/starplus" data-content-title="StarPlus" data-content-type="Navigation" data-list-type="Header" href="/starplus" onclick="ga('send', 'event', 'TSOL NAVI', 'Mobile', '/StarPlus/');" target="">StarPlus
#                     </a>
# </li>
# <li class="navigation-section">
# <a class="navigation-title" data-content-id="https://www.thestar.com.my/news" data-content-title="News" data-content-type="Navigation" data-list-type="Header" href="/news" onclick="ga('send', 'event', 'TSOL NAVI', 'Mobile', '/News/');" target="">News
#                     </a>
# <ul class="navigation-children">
# <li>
# <a data-content-id="https://www.thestar.com.my/news/latest" data-content-title="Latest" data-content-type="Navigation" data-list-type="Header" href="/news/latest" onclick="ga('send', 'event' , 'TSOL NAVI' , 'Mobile' , '/News/Latest/' ); " target="">Latest
#                             </a>
# </li>
# <li>
# <a data-content-id="https://www.thestar.com.my/news/nation" data-content-title="Nation" data-content-type="Navigation" data-list-type="Header" href="/news/nation" onclick="ga('send', 'event' , 'TSOL NAVI' , 'Mobile' , '/News/Nation/' ); " target="">Nation
#                             </a>
# </li>
# <li>
# <a data-content-id="https://www.thestar.com.my/news/world" data-content-title="World" data-content-type="Navigation" data-list-type="Header" href="/news/world" onclick="ga('send', 'event' , 'TSOL NAVI' , 'Mobile' , '/News/World/' ); " target="">World
#                             </a>
# </li>
# <li>
# <a data-content-id="https://www.thestar.com.my/news/environment" data-content-title="Environment" data-content-type="Navigation" data-list-type="Header" href="/news/environment" onclick="ga('send', 'event' , 'TSOL NAVI' , 'Mobile' , '/News/Environment/' ); " target="">Environment
#                             </a>
# </li>
# <li>
# <a data-content-id="https://www.thestar.com.my/news/in-other-media" data-content-title="In Other Media" data-content-type="Navigation" data-list-type="Header" href="/news/in-other-media" onclick="ga('send', 'event' , 'TSOL NAVI' , 'Mobile' , '/News/In-Other-Media/' ); " target="">In Other Media
#                             </a>
# </li>
# <li>
# <a data-content-id="https://www.thestar.com.my/news/true-or-not" data-content-title="True or Not" data-content-type="Navigation" data-list-type="Header" href="/news/true-or-not" onclick="ga('send', 'event' , 'TSOL NAVI' , 'Mobile' , '/News/True-Or-Not/' ); " target="">True or Not
#                             </a>
# </li>
# <li>
# <a data-content-id="https://www.thestar.com.my/news/focus" data-content-title="Focus" data-content-type="Navigation" data-list-type="Header" href="/news/focus" onclick="ga('send', 'event' , 'TSOL NAVI' , 'Mobile' , '/News/Focus/' ); " target="">Focus
#                             </a>
# </li>
# </ul>
# </li>
# <li class="navigation-section">
# <a class="navigation-title" data-content-id="https://www.thestar.com.my/aseanplus" data-content-title="Asean+" data-content-type="Navigation" data-list-type="Header" href="/aseanplus" onclick="ga('send', 'event', 'TSOL NAVI', 'Mobile', '/AseanPlus/');" target="">Asean+
#                     </a>
# </li>
# <li class="navigation-section">
# <a class="navigation-title" data-content-id="https://www.thestar.com.my/business" data-content-title="Business" data-content-type="Navigation" data-list-type="Header" href="/business" onclick="ga('send', 'event', 'TSOL NAVI', 'Mobile', '/Business/');" target="">Business
#                     </a>
# <ul class="navigation-children">
# <li>
# <a data-content-id="https://www.thestar.com.my/business" data-content-title="News" data-content-type="Navigation" data-list-type="Header" href="/business" onclick="ga('send', 'event' , 'TSOL NAVI' , 'Mobile' , '/Business/' ); " target="">News
#                             </a>
# </li>
# <li>
# <a data-content-id="https://www.thestar.com.my/business/smebiz" data-content-title="SMEBiz" data-content-type="Navigation" data-list-type="Header" href="/business/smebiz" onclick="ga('send', 'event' , 'TSOL NAVI' , 'Mobile' , '/Business/Smebiz/' ); " target="">SMEBiz
#                             </a>
# </li>
# <li>
# <a data-content-id="https://www.thestar.com.my/business/insight" data-content-title="Insight" data-content-type="Navigation" data-list-type="Header" href="/business/insight" onclick="ga('send', 'event' , 'TSOL NAVI' , 'Mobile' , '/Business/Insight/' ); " target="">Insight
#                             </a>
# </li>
# <li>
# <a data-content-id="https://www.thestar.com.my/business/unit-trust" data-content-title="Unit Trust" data-content-type="Navigation" data-list-type="Header" href="/business/unit-trust" onclick="ga('send', 'event' , 'TSOL NAVI' , 'Mobile' , '/Business/Unit-Trust/' ); " target="">Unit Trust
#                             </a>
# </li>
# <li>
# <a data-content-id="https://www.thestar.com.my/business/exchange-rates" data-content-title="Exchange Rates" data-content-type="Navigation" data-list-type="Header" href="/business/exchange-rates" onclick="ga('send', 'event' , 'TSOL NAVI' , 'Mobile' , '/Business/Exchange-Rates/' ); " target="">Exchange Rates
#                             </a>
# </li>
# <li>
# <a data-content-id="http://biz.thestar.com.my/portfolio/" data-content-title="My Portfolio" data-content-type="Outbound Referral" data-list-type="Header" href="http://biz.thestar.com.my/portfolio/" onclick="ga('send', 'event' , 'TSOL NAVI' , 'Mobile' , 'http://biz.thestar.com.my/portfolio/' ); " target="_blank">My Portfolio
#                             </a>
# </li>
# </ul>
# </li>
# <li class="navigation-section">
# <a class="navigation-title" data-content-id="https://www.thestar.com.my/business/marketwatch" data-content-title="Market Watch" data-content-type="Navigation" data-list-type="Header" href="/business/marketwatch" onclick="ga('send', 'event', 'TSOL NAVI', 'Mobile', '/Business/MarketWatch/');" target="">Market Watch
#                     </a>
# <ul class="navigation-children">
# <li>
# <a data-content-id="https://www.thestar.com.my/business/marketwatch" data-content-title="Bursa Overview" data-content-type="Navigation" data-list-type="Header" href="/business/marketwatch" onclick="ga('send', 'event' , 'TSOL NAVI' , 'Mobile' , '/Business/Marketwatch/' ); " target="">Bursa Overview
#                             </a>
# </li>
# <li>
# <a data-content-id="https://www.thestar.com.my/business/martketwatch/stock-list" data-content-title="Market Movers" data-content-type="Navigation" data-list-type="Header" href="/business/martketwatch/Stock-List" onclick="ga('send', 'event' , 'TSOL NAVI' , 'Mobile' , '/Business/Martketwatch/Stock-List/' ); " target="">Market Movers
#                             </a>
# </li>
# <li>
# <a data-content-id="https://www.thestar.com.my/business/martketwatch/financial-results" data-content-title="Financial Results" data-content-type="Navigation" data-list-type="Header" href="/business/martketwatch/Financial-Results" onclick="ga('send', 'event' , 'TSOL NAVI' , 'Mobile' , '/Business/Martketwatch/Financial-Results/' ); " target="">Financial Results
#                             </a>
# </li>
# <li>
# <a data-content-id="https://www.thestar.com.my/business/martketwatch/dividends" data-content-title="Dividends" data-content-type="Navigation" data-list-type="Header" href="/business/martketwatch/Dividends" onclick="ga('send', 'event' , 'TSOL NAVI' , 'Mobile' , '/Business/Martketwatch/Dividends/' ); " target="">Dividends
#                             </a>
# </li>
# <li>
# <a data-content-id="https://www.thestar.com.my/business/martketwatch/bonus" data-content-title="Bonus" data-content-type="Navigation" data-list-type="Header" href="/business/martketwatch/Bonus" onclick="ga('send', 'event' , 'TSOL NAVI' , 'Mobile' , '/Business/Martketwatch/Bonus/' ); " target="">Bonus
#                             </a>
# </li>
# <li>
# <a data-content-id="https://www.thestar.com.my/business/martketwatch/ipo" data-content-title="IPO" data-content-type="Navigation" data-list-type="Header" href="/business/martketwatch/IPO" onclick="ga('send', 'event' , 'TSOL NAVI' , 'Mobile' , '/Business/Martketwatch/IPO/' ); " target="">IPO
#                             </a>
# </li>
# </ul>
# </li>
# <li class="navigation-section">
# <a class="navigation-title" data-content-id="https://www.thestar.com.my/sport" data-content-title="Sport" data-content-type="Navigation" data-list-type="Header" href="/sport" onclick="ga('send', 'event', 'TSOL NAVI', 'Mobile', '/Sport/');" target="">Sport
#                     </a>
# <ul class="navigation-children">
# <li>
# <a data-content-id="https://www.thestar.com.my/sport/football" data-content-title="Football" data-content-type="Navigation" data-list-type="Header" href="/sport/football" onclick="ga('send', 'event' , 'TSOL NAVI' , 'Mobile' , '/Sport/Football/' ); " target="">Football
#                             </a>
# </li>
# <li>
# <a data-content-id="https://www.thestar.com.my/sport/golf" data-content-title="Golf" data-content-type="Navigation" data-list-type="Header" href="/sport/golf" onclick="ga('send', 'event' , 'TSOL NAVI' , 'Mobile' , '/Sport/Golf/' ); " target="">Golf
#                             </a>
# </li>
# <li>
# <a data-content-id="https://www.thestar.com.my/sport/badminton" data-content-title="Badminton" data-content-type="Navigation" data-list-type="Header" href="/sport/badminton" onclick="ga('send', 'event' , 'TSOL NAVI' , 'Mobile' , '/Sport/Badminton/' ); " target="">Badminton
#                             </a>
# </li>
# <li>
# ...
# <i class="icon sprite-icon"></i>
# </a>
# </li>
# </ul>
# <ul class="footer-n__downloads">
# <li><a class="playstore-large" data-content-id="https://play.google.com/store/apps/details?id=com.knx.thestarmobile" data-content-title="Google Play" data-content-type="App Download" data-list-type="Footer" href="https://play.google.com/store/apps/details?id=com.knx.thestarmobile" target="_blank"><i class="icon sprite-icon"></i>
# </a>
# </li>
# <li>
# <a class="appstore-large" data-content-id="https://itunes.apple.com/app/the-star-mobile/id428184176?mt=8" data-content-title="App Store" data-content-type="App Download" data-list-type="Footer" href="https://itunes.apple.com/app/the-star-mobile/id428184176?mt=8" target="_blank"><i class="icon sprite-icon"></i>
# </a>
# </li>
# <li><a class="huawei" data-content-id="http://cdc.hispace.hicloud.com/000000WJ" data-content-title="APPGALLERY" data-content-type="App Download" data-list-type="Footer" href="http://cdc.hispace.hicloud.com/000000WJ" target="_blank">
# <i class="icon sprite-icon"></i>
# </a>
# </li>
# </ul>
# </div>
# <div class="footer-n__inner footer-n__newsletter">
# <iframe frameborder="0" scrolling="no" src="https://sites.thestar.com.my/tsolnewsletter/subscription_footer.aspx " style="width: 100%; min-width: 200px;"></iframe>
# </div>
# </footer>
# <div class="footer-bottom">
# <div class="container">
# <p>Copyright © 1995-
#             <span id="spanCopyright">
# <script type="text/javascript">
#                     $(document).ready(function () {
#                         var theDate = new Date();
#                         $('#spanCopyright').text(theDate.getFullYear())
#                     })
#                 </script>
# </span> Star Media Group Berhad (10894D)</p><p>Best viewed on Chrome browsers.</p>
# </div>
# </div>
# <div class="mobilenav">
# <div class="container">
# <nav>
# <ul>
# <li id="sticky-home">
# <a data-content-id="https://www.thestar.com.my" data-content-title="Home" data-content-type="Navigation" data-list-type="Bottom Sticky Menu" href="/" onclick="ga('send', 'event', 'TSOL STICKY NAVI', 'Standard', '/Home/');">
# <div class="mobilenav__icon home"></div>
#                         Home
#                     </a>
# </li>
# <li id="sticky-foryou">
# <a data-content-id="https://www.thestar.com.my/foryou" data-content-title="For You" data-content-type="Navigation" data-list-type="Bottom Sticky Menu" href="/foryou" onclick="ga('send', 'event', 'TSOL STICKY NAVI', 'Standard', '/For You/');">
# <div class="mobilenav__icon paper"></div>
#                         For You
#                     </a>
# </li>
# <li id="sticky-saved-articles">
# <a data-content-id="https://www.thestar.com.my/saved-articles" data-content-title="Bookmark" data-content-type="Navigation" data-list-type="Bottom Sticky Menu" href="/saved-articles" onclick="ga('send', 'event', 'TSOL STICKY NAVI', 'Standard', '/Saved-Articles/');">
# <div class="mobilenav__icon bookmark"></div>
#                         Bookmark
#                     </a>
# </li>
# <li id="podcast">
# <div class="audionav__toggle">
# <div class="mobilenav__icon podcast"></div>
#                         Audio
#                     </div>
# </li>
# <li id="searchnav">
# <div class="searchnav__toggle">
# <div class="mobilenav__icon search"></div>
#                         Search
#                     </div>
# </li>
# </ul>
# </nav>
# </div>
# </div>
# <div class="drop drop--audio">
# </div>
# <div class="drop drop--search">
# <div class="drop__close">
# <div class="drop__closebutton">
# <i class="fa fa-times"></i>
# </div>
# </div>
# <div class="container" id="drop--search--container">
# <form action="search" id="searchform" method="GET" role="form">
# <div class="input-group">
# <input autofocus="" class="form-control" id="qTextBox" name="q" onkeypress="searchKeyPress(event, 'btnSearch' ); " placeholder="What are you looking for?" type="text"/>
# <div id="qStockCodeHolder">
# <input id="qStockCodeVal" type="hidden" value=""/>
# </div>
# <div class="input-group-btn">
# <input class="btn btn-default" id="btnSearch" onclick="
#                             if ($.trim($('#qTextBox').val()).length &gt;=3) {
#                                 jQuery('#qTextBox').addClass('loadinggif');
#                                 post('/search/', { q: document.getElementById('qTextBox').value, qsort: 'newest', qrec: '10', qstockcode: document.getElementById('qStockCodeVal').value }, 'get');
#                                 ga('send', 'event', 'TSOL NAVI', 'Extra-Panel', 'Search Button');
#                             }else if($.trim($('#qTextBox').val()).length &gt; 0 &amp;&amp; $.trim($('#qTextBox').val()).length &lt;3){
#                                 jQuery('#qTextBox').removeClass('loadinggif');
#                                 alert('Please enter at least 3 characters for search phrase.');
#                             }else{
#                                 jQuery('#qTextBox').removeClass('loadinggif');
#                                 alert('Please enter a search phrase.');
#                             }
#                             " style="font-weight: bold" type="button" value="Search"/>
# <a class="btn btn-default adv-search-link" data-content-id="https://www.thestar.com.my/search/?adv=1" data-content-title="Advance Search" data-content-type="Navigation" data-list-type="Header" href="/search?adv=1" onclick="ga('send', 'event' , 'TSOL NAVI' , 'Extra-Panel' , 'Advance Search' ); " onmousedown="searchAdvanceClick(this,'qTextBox')" style="font-weight: 900"><i class="icon sprite-icon plus"></i>
# </a>
# </div>
# </div>
# </form>
# </div>
# </div>
# </div>
# <!-- /page content -->
# <!-- Global Footer scripts -->
# <!-- Start Footer Script -->
# <input id="hfldUrl" name="hfldUrl" type="hidden" value="HNQ8Auw31qgZZU47ZjHUhEODef8iN5x8uygAL4ts77ne7pSw6Jbb3oIHo/rAyVkFL/OVZvFEwkY5yBtacxcalw=="/>
# <script type="text/javascript">  var adblock = true; </script>
# <script src="https://cdn.thestar.com.my/Themes/js/cXense/adframe.js"></script>
# <script src="https://cdn.thestar.com.my/Themes/js/cXense/PaywallBypassBlocker.min.js" type="text/javascript"></script>
# <script charset="utf-8" src="https://cdn.thestar.com.my/GlobalBar/global-bar.min.js?v=20210824"></script>
# <script src="https://cdn.thestar.com.my/Themes/js/bootstrap.min.js"></script>
# <script src="https://cdn.thestar.com.my/Themes/js/bookmark.min.js?v=20210708"></script>
# <script src="https://cdn.thestar.com.my/Themes/js/loginstatusV2.js?v=20200420"></script>
# <script src="https://cdn.thestar.com.my/Components/Audio/rangetouch.js"></script>
# <script src="https://cdn.thestar.com.my/Components/Audio/audiov11.js"></script>
# <script src="https://cdn.thestar.com.my/Themes/js/lazysizes.min.js"></script>
# <script src="/theme_metro/js/script.js?v=20210315"></script>
# <noscript><iframe height="0" src="//www.googletagmanager.com/ns.html?id=GTM-PVM4TH" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# '//www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-PVM4TH');</script>
# <script>
# var _comscore = _comscore || [];
# _comscore.push({ c1: "2", c2: "6035691" });
# (function () {
# var s = document.createElement("script"), el = document.getElementsByTagName("script")[0]; s.async = true;
# s.src = (document.location.protocol == "https:" ? "https://sb" : "http://b") + ".scorecardresearch.com/beacon.js";
# el.parentNode.insertBefore(s, el);
# })();
# </script>
# <noscript>
# <img src="http://b.scorecardresearch.com/p?c1=2&amp;c2=6035691&amp;cv=2.0&amp;cj=1"/>
# </noscript>
# <script type="text/javascript">
# setTimeout(function(){var a=document.createElement("script");
# var b=document.getElementsByTagName("script")[0];
# a.src=document.location.protocol+"//script.crazyegg.com/pages/scripts/0012/7021.js?"+Math.floor(new Date().getTime()/3600000);
# a.async=true;a.type="text/javascript";b.parentNode.insertBefore(a,b)}, 1);
# </script>
# <!--For engagement-->
# <script type="text/javascript">$(document).ready(function(){if(checkCookie('engagement_box')!=null){var cookie=jQuery.parseJSON(checkCookie('engagement_box'));var new_cookie={};var old_cookie=[];for(var key in cookie){if(cookie[key].timestamp!=undefined){old_cookie.push({key:key,id:cookie[key].id,a:cookie[key].answer,n:cookie[key].timestamp})}}
# if(old_cookie.length>0){old_cookie.sort(function(x,y){return x.n-y.n});var i=0;for(var key in old_cookie){new_cookie[old_cookie[key].key]={n:i,id:old_cookie[key].id,a:old_cookie[key].a}
# i++}}
# addCookie('engagement_box',JSON.stringify(new_cookie),7)}});function addCookie(name,value,days){var expires="";if(days){var date=new Date();date.setTime(date.getTime()+(days*24*60*60*1000));expires="; expires="+date.toUTCString()}
# document.cookie=name+"="+(value||"")+expires+"; path=/"}
# function checkCookie(name){var nameEQ=name+"=";var ca=document.cookie.split(';');for(var i=0;i<ca.length;i++){var c=ca[i];while(c.charAt(0)==' ')c=c.substring(1,c.length);if(c.indexOf(nameEQ)==0)return c.substring(nameEQ.length,c.length)}
# return null}</script>
# <!-- user dialog tutorial 8/7/2020 -->
# <script src="https://cdn.thestar.com.my/Themes/js/anno.js?v=20201130"></script><link href="https://cdn.thestar.com.my/Themes/css/anno.css" rel="stylesheet" type="text/css"/>
# <script src="https://cdn.thestar.com.my/Themes/js/userTour.min.js?v=20201123" type="text/javascript"></script>
# <!-- end user dialog tutorial 8/7/2020 -->
# <!-- vodus here, removed on 2021/09/29 -->
# <!-- End Footer Script -->
# <!--BEGIN Flyin Pullout PDF-->
# <link href="https://cdn.thestar.com.my/Components/Flyin/flyin.css" rel="stylesheet"/><link href="https://fonts.googleapis.com/css?family=Lato:400,900" rel="stylesheet"/><div class="detail" id="widgetbox" style="display:none;"><a class="close" id="widgetBoxCloseButton"><img src="https://cdn.thestar.com.my/Themes/img/times-solid.png" style="width: 12px; height:12px;"/></a><div class="openBox"><div class="flex-container open-box-title"><h3 id="widget-title" style="display: block; font-size: 1.17em; margin-block-start: 1em;margin-block-end: 1em; margin-inline-start: 0px;margin-inline-end: 0px; fontweight: bold;"></h3></div><div class="flex-container" style="margin-bottom:11px;"><div><img class="thumbPull" id="widget_img" style="width: 150px;"/></div><div><p id="widget-desc" style="font-size: 0.875em; color: #4a4a4a !important; font-weight: 400;line-height: 1.37em;padding-left: 12px; margin-bottom: 10px;"></p> </div></div><div class="flex-container"><a class="widget-link" id="widget-link">Download now!</a></div></div><div class="flex-container" id="formbox" style="display: none;"><form action="" id="flyinform" method="post"><p>We would love to keep you posted on the latest promotion. Kindly fill the form below</p><div class="formIn"><div><input class="" id="txtName" name="txtName" placeholder="Name" required="" type="text"/></div><div><input id="email" name="email" placeholder="Email" type="email"/></div><div><input id="phone" maxlength="15" name="phone" pattern="[0-9]{10,}" placeholder="Phone" type="number"/></div></div><div class="validate"></div><input type="submit" value="Submit"/><div class="skip"><a id="widget-skip">Skip</a></div><div class="term"><div>Disclaimer: by clicking the Submit button, it is deemed that you consent to the rules and terms set forth in the <a href="https://www.thestar.com.my/privacy/" target="_blank">Privacy Policy</a> as well as <a href="https://www.thestar.com.my/terms/" target="_blank">Terms and Conditions</a> set forth by this site.</div></div></form></div><div class="thankYouBox thanks" style="display: none;margin-left: 40px;"><div class="flex-container thanksbox"><div class="svg-down"></div><div><h3 style="display: block; font-size: 1.17em; margin-block-end: 1em; margin-inline-start: 0px;margin-inline-end: 0px; fontweight: bold;">Thank you for downloading.</h3></div></div><div class="flex-container"><div><p>We hope you enjoy this feature!</p><span>Didn't work? Try <a class="widget-link2" id="widget-link2">downloading</a> again.</span></div></div></div></div>
# <script src="https://cdn.thestar.com.my/Components/Flyin/Flyin_20210318_1.js" type="text/javascript"></script>
# <!--END Flyin Pullout PDF--> <!--resources common js_includes.blade.php-->
# <!-- theme includes js_includes.blade.php -->
# <!--Po.st for social icons in article page-->
# <script type="text/javascript">
# //Remove po.st social share
# //    (function () {
# //        var s = document.createElement('script');
# //        s.type = 'text/javascript';
# //        s.async = true;
# //        s.src = ('https:' == document.location.protocol ? 'https://s' : 'http://i')
# //          + '.po.st/static/v4/post-widget.js#publisherKey=gbc1mg0m85gf08mf3jlb';
# //        var x = document.getElementsByTagName('script')[0];
# //        x.parentNode.insertBefore(s, x);
# //     })();
# //window.pwidget_config = {
# //    publisherKey: 'wid-47r2u0p7',
# //    defaults: { radius: "circle", buttonColor: "default", buttonBackground: "default", label: "false", size: "24", counter: false, padding: true, view: "auto", shareNewWindow: true, services: { twitter: { via: "staronline" } }, jumboPosition: "first", },
# //    onload: function () {
# //        if (navigator.userAgent.match(/Android/i) || navigator.userAgent.match(/iPhone/i) || navigator.userAgent.match(/iPad/i) || navigator.userAgent.match(/iPod/i) || navigator.userAgent.match(/Windows Phone/i)) {
# //           window.postPlatform.createWidget('.post-Wiz-Custom-Items', { buttons: [{ "id": "facebook" }, { "id": "twitter" }, { "id": "linkedin" }, { "id": "line" }, { "id": "reddit" }, { "id": "whatsapp" }, { "id": "email" }], });
# //        }
# //        else window.postPlatform.createWidget('.post-Wiz-Custom-Items', { buttons: [{ "id": "facebook" }, { "id": "twitter" }, { "id": "linkedin" }, { "id": "line" }, { "id": "reddit" }, { "id": "print" }, { "id": "email" }], });
# //    }
# //};
#
# //Added for ajax load today picture
# $(".slick-next").click(function(){
#     setTimeout(function() {
#       addthis.layers.refresh();
#     }, 1000);
# });
#
# $(".slick-prev").click(function(){
#     setTimeout(function() {
#       addthis.layers.refresh();
#     }, 1000);
# });
# //Added for ajax load today picture
# </script>
# <!-- Cxense script begin -->
# <script type="text/javascript">
#
# var pageType = jQuery('meta[name=pageType]').attr("content");
#
# if(pageType == "article"){
#     var cX = window.cX = window.cX || {}; cX.callQueue = cX.callQueue || [];
#     var cxenseRandom = jQuery('meta[name=cxenseRandom]').attr("content");
#     cX.CCE = cX.CCE || {}; cX.CCE.callQueue = cX.CCE.callQueue || [];
#     cX.callQueue.push(['setRandomId',cxenseRandom]); // server side generated id
#     cX.callQueue.push(['setSiteId', '1145278932220698298']);
#
#
#             cX.callQueue.push(['setCustomParameters', { 'usergroup': 'anonymous' }]);
#
#     cX.CCE.callQueue.push(['sendPageViewEvent','smg', '0240b44ae7cc929b3991ca5c126d42a11e5582d4']);
# }
# else{
#     var cX = cX || {}; cX.callQueue = cX.callQueue || [];
#     cX.callQueue.push(['setSiteId', '1145278932220698298']);
#     cX.callQueue.push(['sendPageViewEvent']);
# }
# </script>
# <!-- Cxense script end -->
# <!-- NetCore -->
# <script src="//tw.netcore.co.in/smartechclient.js"></script>
# <script>
#   smartech('create', 'ADGMOT35CHFLVDHBJNIG50K968P0V61ULQ6VTDV1B4AH6RHKPIVG');
#   smartech('register', '1ea761fa10f93f18df46ddc3b4f7b01a');
#   smartech('identify', '');
#   smartech('dispatch',1,{});
# </script>
# <!-- End NetCore -->
# <!-- Widget JS links -->
# <script type="text/javascript">window.NREUM||(NREUM={});NREUM.info={"beacon":"bam-cell.nr-data.net","licenseKey":"ef8b08f3e1","applicationID":"379274163","transactionName":"ZwdaMkpTW0AEWhYKDl5NeQVMW1pdSngSEz14FkwWZHFaXRFLDQ8NVRBLOnFcUVYdeg0NFUINVApdQHVaC10HGw==","queueTime":0,"applicationTime":214,"atts":"S0BZRAJJSE4=","errorBeacon":"bam-cell.nr-data.net","agent":""}</script></body>
# </html>

# %%
data = []
data1= []
import csv

# %%
from urllib.request import urlopen, HTTPError
from datetime import datetime, timedelta

# %%
from bs4 import BeautifulSoup 
base_url = 'https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno='
# Add 1 because Python range.
url_list = ["{}{}".format(base_url, str(page)) for page in range(1, 408)]
s=[]
for url in url_list:
    print (url)
    s.append(url)
# Out:
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=1
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=2
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=3
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=4
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=5
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=6
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=7
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=8
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=9
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=10
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=11
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=12
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=13
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=14
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=15
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=16
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=17
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=18
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=19
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=20
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=21
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=22
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=23
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=24
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=25
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=26
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=27
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=28
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=29
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=30
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=31
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=32
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=33
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=34
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=35
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=36
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=37
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=38
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=39
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=40
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=41
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=42
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=43
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=44
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=45
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=46
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=47
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=48
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=49
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=50
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=51
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=52
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=53
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=54
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=55
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=56
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=57
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=58
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=59
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=60
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=61
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=62
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=63
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=64
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=65
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=66
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=67
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=68
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=69
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=70
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=71
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=72
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=73
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=74
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=75
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=76
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=77
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=78
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=79
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=80
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=81
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=82
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=83
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=84
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=85
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=86
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=87
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=88
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=89
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=90
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=91
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=92
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=93
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=94
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=95
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=96
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=97
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=98
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=99
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=100
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=101
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=102
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=103
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=104
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=105
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=106
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=107
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=108
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=109
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=110
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=111
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=112
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=113
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=114
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=115
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=116
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=117
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=118
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=119
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=120
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=121
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=122
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=123
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=124
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=125
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=126
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=127
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=128
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=129
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=130
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=131
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=132
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=133
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=134
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=135
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=136
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=137
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=138
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=139
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=140
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=141
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=142
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=143
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=144
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=145
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=146
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=147
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=148
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=149
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=150
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=151
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=152
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=153
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=154
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=155
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=156
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=157
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=158
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=159
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=160
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=161
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=162
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=163
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=164
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=165
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=166
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=167
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=168
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=169
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=170
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=171
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=172
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=173
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=174
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=175
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=176
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=177
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=178
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=179
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=180
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=181
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=182
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=183
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=184
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=185
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=186
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=187
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=188
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=189
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=190
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=191
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=192
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=193
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=194
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=195
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=196
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=197
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=198
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=199
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=200
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=201
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=202
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=203
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=204
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=205
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=206
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=207
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=208
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=209
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=210
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=211
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=212
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=213
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=214
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=215
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=216
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=217
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=218
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=219
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=220
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=221
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=222
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=223
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=224
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=225
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=226
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=227
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=228
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=229
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=230
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=231
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=232
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=233
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=234
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=235
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=236
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=237
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=238
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=239
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=240
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=241
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=242
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=243
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=244
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=245
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=246
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=247
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=248
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=249
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=250
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=251
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=252
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=253
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=254
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=255
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=256
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=257
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=258
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=259
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=260
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=261
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=262
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=263
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=264
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=265
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=266
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=267
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=268
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=269
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=270
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=271
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=272
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=273
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=274
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=275
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=276
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=277
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=278
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=279
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=280
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=281
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=282
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=283
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=284
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=285
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=286
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=287
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=288
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=289
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=290
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=291
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=292
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=293
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=294
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=295
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=296
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=297
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=298
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=299
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=300
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=301
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=302
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=303
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=304
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=305
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=306
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=307
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=308
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=309
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=310
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=311
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=312
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=313
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=314
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=315
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=316
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=317
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=318
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=319
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=320
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=321
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=322
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=323
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=324
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=325
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=326
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=327
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=328
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=329
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=330
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=331
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=332
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=333
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=334
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=335
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=336
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=337
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=338
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=339
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=340
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=341
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=342
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=343
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=344
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=345
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=346
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=347
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=348
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=349
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=350
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=351
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=352
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=353
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=354
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=355
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=356
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=357
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=358
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=359
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=360
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=361
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=362
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=363
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=364
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=365
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=366
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=367
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=368
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=369
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=370
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=371
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=372
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=373
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=374
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=375
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=376
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=377
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=378
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=379
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=380
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=381
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=382
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=383
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=384
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=385
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=386
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=387
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=388
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=389
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=390
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=391
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=392
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=393
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=394
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=395
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=396
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=397
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=398
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=399
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=400
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=401
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=402
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=403
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=404
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=405
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=406
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=407

# %%
for pg in s:
    # query the website and return the html to the variable 'page'
    page = urllib.request.urlopen(pg)
    try:
        search_response = urllib.request.urlopen(pg)
    except urllib.request.HTTPError:
        pass
    # parse the html using beautiful soap and store in variable `soup`
    soup = BeautifulSoup(page, 'html.parser')
    # Take out the <div> of name and get its value
    ls = [x.get_text(strip=True) for x in soup.find_all("h2", {"class": "f18"})]
    ls1=  [x.get_text(strip=True) for x in soup.find_all("span", {"class": "date"})]
    # save the data in tuple
    data.append((ls))
    data1.append(ls1)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1316                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1317                           encode_chunked=req.has_header('Transfer-encoding'))
#    1318             except OSError as err: # timeout error
#
# ~/anaconda3/lib/python3.7/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1243         """Send a complete request to the server."""
# -> 1244         self._send_request(method, url, body, headers, encode_chunked)
#    1245
#
# ~/anaconda3/lib/python3.7/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1289             body = _encode(body, 'body')
# -> 1290         self.endheaders(body, encode_chunked=encode_chunked)
#    1291
#
# ~/anaconda3/lib/python3.7/http/client.py in endheaders(self, message_body, encode_chunked)
#    1238             raise CannotSendHeader()
# -> 1239         self._send_output(message_body, encode_chunked=encode_chunked)
#    1240
#
# ~/anaconda3/lib/python3.7/http/client.py in _send_output(self, message_body, encode_chunked)
#    1025         del self._buffer[:]
# -> 1026         self.send(msg)
#    1027
#
# ~/anaconda3/lib/python3.7/http/client.py in send(self, data)
#     965             if self.auto_open:
# --> 966                 self.connect()
#     967             else:
#
# ~/anaconda3/lib/python3.7/http/client.py in connect(self)
#    1405
# -> 1406             super().connect()
#    1407
#
# ~/anaconda3/lib/python3.7/http/client.py in connect(self)
#     937         self.sock = self._create_connection(
# --> 938             (self.host,self.port), self.timeout, self.source_address)
#     939         self.sock.setsockopt(socket.IPPROTO_TCP, socket.TCP_NODELAY, 1)
#
# ~/anaconda3/lib/python3.7/socket.py in create_connection(address, timeout, source_address)
#     726     if err is not None:
# --> 727         raise err
#     728     else:
#
# ~/anaconda3/lib/python3.7/socket.py in create_connection(address, timeout, source_address)
#     715                 sock.bind(source_address)
# --> 716             sock.connect(sa)
#     717             # Break explicitly a reference cycle
#
# OSError: [Errno 101] Network is unreachable
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# <ipython-input-11-de1183ca7ad2> in <module>
#       1 for pg in s:
#       2     # query the website and return the html to the variable 'page'
# ----> 3     page = urllib.request.urlopen(pg)
#       4     try:
#       5         search_response = urllib.request.urlopen(pg)
#
# ~/anaconda3/lib/python3.7/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# ~/anaconda3/lib/python3.7/urllib/request.py in open(self, fullurl, data, timeout)
#     523             req = meth(req)
#     524
# --> 525         response = self._open(req, data)
#     526
#     527         # post-process response
#
# ~/anaconda3/lib/python3.7/urllib/request.py in _open(self, req, data)
#     541         protocol = req.type
#     542         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 543                                   '_open', req)
#     544         if result:
#     545             return result
#
# ~/anaconda3/lib/python3.7/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     501         for handler in handlers:
#     502             func = getattr(handler, meth_name)
# --> 503             result = func(*args)
#     504             if result is not None:
#     505                 return result
#
# ~/anaconda3/lib/python3.7/urllib/request.py in https_open(self, req)
#    1358         def https_open(self, req):
#    1359             return self.do_open(http.client.HTTPSConnection, req,
# -> 1360                 context=self._context, check_hostname=self._check_hostname)
#    1361
#    1362         https_request = AbstractHTTPHandler.do_request_
#
# ~/anaconda3/lib/python3.7/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1317                           encode_chunked=req.has_header('Transfer-encoding'))
#    1318             except OSError as err: # timeout error
# -> 1319                 raise URLError(err)
#    1320             r = h.getresponse()
#    1321         except:
#
# URLError: <urlopen error [Errno 101] Network is unreachable>
