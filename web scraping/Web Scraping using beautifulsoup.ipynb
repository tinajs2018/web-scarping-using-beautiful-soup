# %%
pip install bs4
pip install urllib

# %%
import csv
from bs4 import BeautifulSoup  
from urllib.request import urlopen

# %%
html= urlopen('https://en.wikipedia.org/wiki/Comparison_of_programming_languages')

# %%
html

# %%
soup=BeautifulSoup(html,'html.parser')
print(soup)
# Out:
# <!DOCTYPE html>
#
# <html class="client-nojs" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Comparison of programming languages - Wikipedia</title>
# ...

# %%
print(soup.prettify)
# Out:
# <bound method Tag.prettify of <!DOCTYPE html>
#
# <html class="client-nojs" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Comparison of programming languages - Wikipedia</title>
# ...

# %%
table=soup.findAll('table',{'class':'wikitable sortable'})[0]
table
# Out:
# <table class="wikitable sortable" style="text-align:center;">
# <tbody><tr align="center">
# <th>Language
# </th>
# <th>Intended use
# </th>
# <th><a href="/wiki/Imperative_programming" title="Imperative programming">Imperative</a>
# </th>
# <th><a href="/wiki/Object-oriented_programming" title="Object-oriented programming">Object-oriented</a>
# </th>
# <th><a href="/wiki/Functional_programming" title="Functional programming">Functional</a>
# </th>
# <th><a href="/wiki/Procedural_programming" title="Procedural programming">Procedural</a>
# </th>
# <th><a href="/wiki/Generic_programming" title="Generic programming">Generic</a>
# </th>
# <th><a href="/wiki/Reflective_programming" title="Reflective programming">Reflective</a>
# </th>
# <th><a href="/wiki/Event-driven_programming" title="Event-driven programming">Event-driven</a>
# </th>
# <th>Other <a href="/wiki/Programming_paradigm" title="Programming paradigm">paradigm</a>(s)
# </th>
# ...

# %%
rows=soup.findAll('tr')
rows
# Out:
# [<tr><th class="sidebar-title"><a class="mw-selflink selflink">Factors of comparison <br/>of programming languages</a></th></tr>,
#  <tr><td class="sidebar-content" style="text-align: left">
#  <ul><li><a class="mw-selflink selflink">General comparison</a></li>
#  <li><a href="/wiki/Assignment_(computer_science)#Notation" title="Assignment (computer science)">Assignment</a></li>
#  <li><a href="/wiki/Comparison_of_programming_languages_(syntax)" title="Comparison of programming languages (syntax)">Basic syntax</a></li>
#  <li><a href="/wiki/Comparison_of_programming_languages_(basic_instructions)" title="Comparison of programming languages (basic instructions)">Basic instructions</a></li>
#  <li><a href="/wiki/Comment_(computer_programming)#Comparison" title="Comment (computer programming)">Comments</a></li>
#  <li>Control flow
#  <ul><li><a href="/wiki/Foreach_loop#Language_support" title="Foreach loop">Foreach loops</a></li>
# ...

# %%
with open('Lang.csv','wt+',newline="") as f:
    writer=csv.writer(f)
    for i in rows:
        row = []
        for cell in i.findAll(['td','th']):
            row.append(cell.get_text())
        writer.writerow(row)

# %%
import pandas as pd

# %%
a=pd.read_csv('Lang.csv')
a.head()
# Out:
#                              Language\n  \
# 0  1C:Enterprise programming language\n
# 1                    ActionScript 3.0\n
# 2                                 Ada\n
# 3                               Aldor\n
# 4                            ALGOL 58\n
#
#                                       Intended use\n Imperative\n  \
# 0  Application, RAD,  business, general, web, mob...        Yes\n
# 1                    Application, client-side, web\n        Yes\n
# 2          Application, embedded, realtime, system\n        Yes\n
# 3       Highly domain-specific, symbolic computing\n        Yes\n
# 4                                      Application\n        Yes\n
#
#   Object-oriented\n Functional\n Procedural\n Generic\n Reflective\n  \
# 0                \n        Yes\n        Yes\n     Yes\n        Yes\n
# 1             Yes\n        Yes\n           \n        \n           \n
# 2          Yes[2]\n           \n     Yes[3]\n  Yes[4]\n           \n
# ...
